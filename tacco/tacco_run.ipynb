# %%
# 1. M1_POD3
# !python /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py --sc_name M1_POD3 --chip_id M1_D3-Y00852K1 --outdir /data/work/02.result/tacco_251118/02.result/KC/M1_POD3 --modifications ""
# Out:
# Start processing: M1_POD3 | M1_D3-Y00852K1
# Modifications:
# Loading Reference...
# /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py:139: DtypeWarning: Columns (11,13,24,27,28,29,31,32,33,34,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta_sc = pd.read_csv(meta_sc_path, index_col=0)
# /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py:144: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   reference.obs[annotation_key] = meta_sc.loc[reference.obs.index, annotation_key]
# Loading Spatial...
# /opt/conda/lib/python3.10/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Removed cell types < 20 cells: ['KC_ACTA2']
# Raw SC Proportions:
#  kc_1020
# Spi-mig       0.254291
# Bas-prolif    0.237655
# Bas-mig       0.208344
# Spi-I         0.116451
# ...

# %%
# 2. M1_POD7
# !python /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py --sc_name M1_POD7 --chip_id M1_D7-Y00853K1 --outdir /data/work/02.result/tacco_251118/02.result/KC/M1_POD7 --modifications ""
# Out:
# Start processing: M1_POD7 | M1_D7-Y00853K1
# Modifications:
# Loading Reference...
# /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py:139: DtypeWarning: Columns (11,13,24,27,28,29,31,32,33,34,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta_sc = pd.read_csv(meta_sc_path, index_col=0)
# /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py:144: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   reference.obs[annotation_key] = meta_sc.loc[reference.obs.index, annotation_key]
# Loading Spatial...
# /opt/conda/lib/python3.10/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Removed cell types < 20 cells: ['Gra-I', 'Sweat_Gland', 'KC-HS']
# Raw SC Proportions:
#  kc_1020
# Spi-mig       0.298535
# Bas-mig       0.217949
# Bas-I         0.183150
# ...

# %%
# 3. M1_POD14
# !python /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py --sc_name M1_POD14 --chip_id M1_D14-Y00914C3 --outdir /data/work/02.result/tacco_251118/02.result/KC/M1_POD14 --modifications ""
# Out:
# Start processing: M1_POD14 | M1_D14-Y00914C3
# Modifications:
# Loading Reference...
# /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py:139: DtypeWarning: Columns (11,13,24,27,28,29,31,32,33,34,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta_sc = pd.read_csv(meta_sc_path, index_col=0)
# /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py:144: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   reference.obs[annotation_key] = meta_sc.loc[reference.obs.index, annotation_key]
# Loading Spatial...
# /opt/conda/lib/python3.10/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Removed cell types < 20 cells: []
# Raw SC Proportions:
#  kc_1020
# Spi-mig       0.273834
# Bas-mig       0.240186
# Bas-prolif    0.168954
# Spi-I         0.148908
# ...

# %%
# 4. M1_POD21
# !python /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py --sc_name M1_POD21 --chip_id M1_D21-Y00914H1 --outdir /data/work/02.result/tacco_251118/02.result/KC/M1_POD21 --modifications ""
# Out:
# D21 DETECTED. Using direct target path: /data/users/zengxiaoqi/zengxiaoqi_07ef1e4aa8384c83b1fbfa53cc352045/online/002.Identify_pig_cells/07.Monkey_mapping_Cluster/M1_D21-Y00914H1/M1_D21-Y00914H1_SCT.h5ad
# Start processing: M1_POD21 | M1_D21-Y00914H1
# Modifications:
# Loading Reference...
# /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py:152: DtypeWarning: Columns (11,13,24,27,28,29,31,32,33,34,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta_sc = pd.read_csv(meta_sc_path, index_col=0)
# /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py:157: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   reference.obs[annotation_key] = meta_sc.loc[reference.obs.index, annotation_key]
# Loading Spatial...
# /opt/conda/lib/python3.10/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
# ...

# %%
# 5. M2_POD3
# !python /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py --sc_name M2_POD3 --chip_id M2_D3-Y00852GE --outdir /data/work/02.result/tacco_251118/02.result/KC/M2_POD3 --modifications ""

# %%
# 6. M2_POD7
# !python /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py --sc_name M2_POD7 --chip_id M2_D7-Y00853HD --outdir /data/work/02.result/tacco_251118/02.result/KC/M2_POD7 --modifications ""

# %%
# 7. M2_POD14
# !python /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py --sc_name M2_POD14 --chip_id M2_D14-Y00914C5 --outdir /data/work/02.result/tacco_251118/02.result/KC/M2_POD14 --modifications ""

# %%
# 8. M2_POD21
# !python /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py --sc_name M2_POD21 --chip_id M2_D21-Y00914KD --outdir /data/work/02.result/tacco_251118/02.result/KC/M2_POD21 --modifications ""
# Out:
# D21 DETECTED. Using direct target path: /data/users/zengxiaoqi/zengxiaoqi_07ef1e4aa8384c83b1fbfa53cc352045/online/002.Identify_pig_cells/07.Monkey_mapping_Cluster/M2_D21-Y00914KD/M2_D21-Y00914KD_SCT.h5ad
# Start processing: M2_POD21 | M2_D21-Y00914KD
# Modifications:
# Loading Reference...
# /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py:152: DtypeWarning: Columns (11,13,24,27,28,29,31,32,33,34,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta_sc = pd.read_csv(meta_sc_path, index_col=0)
# /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py:157: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   reference.obs[annotation_key] = meta_sc.loc[reference.obs.index, annotation_key]
# Loading Spatial...
# /opt/conda/lib/python3.10/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
# ...

# %%
# 9. M4_POD3
# !python /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py --sc_name M4_POD3 --chip_id M4_D3-Y00852N2 --outdir /data/work/02.result/tacco_251118/02.result/KC/M4_POD3 --modifications ""

# %%
# 10. M4_POD7
# !python /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py --sc_name M4_POD7 --chip_id M4_D7-Y00855D1 --outdir /data/work/02.result/tacco_251118/02.result/KC/M4_POD7 --modifications ""

# %%
# 11. M4_POD14
# !python /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py \
    --sc_name M4_POD14 \
    --chip_id M4_D14-Y00914D2 \
    --outdir /data/work/02.result/tacco_251118/02.result/KC/M4_POD14 \
    --modifications ""

# %%
# 12. M4_POD21
# !python /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py \
    --sc_name M4_POD21 \
    --chip_id M4_D21-Y00914NE \
    --outdir /data/work/02.result/tacco_251118/02.result/KC/M4_POD21 \
    --modifications ""
# Out:
# D21 DETECTED. Using direct target path: /data/users/zengxiaoqi/zengxiaoqi_07ef1e4aa8384c83b1fbfa53cc352045/online/002.Identify_pig_cells/07.Monkey_mapping_Cluster/M4_D21-Y00914NE/M4_D21-Y00914NE_SCT.h5ad
# Start processing: M4_POD21 | M4_D21-Y00914NE
# Modifications:
# Loading Reference...
# /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py:151: DtypeWarning: Columns (11,13,24,27,28,29,31,32,33,34,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta_sc = pd.read_csv(meta_sc_path, index_col=0)
# /data/work/02.result/tacco_251118/tacco_part2_run_zbl.py:156: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   reference.obs[annotation_key] = meta_sc.loc[reference.obs.index, annotation_key]
# Loading Spatial...
# /opt/conda/lib/python3.10/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
# ...
